# %%
from pathlib import Path
from helper_code.rag.load_dataset import setup_embedding_function, load_db_from_dir, load_vectorstore

# %%
# check if vectorstores exist, if not, run milcon_doc_vectorstore.py to create them
if not (Path("./databases/proj/index").exists() and
        Path("./databases/strat26/index").exists() and
        Path("./databases/strat28/index").exists()):

    print("One or more vectorstores are missing. Please run milcon_doc_vectorstore.py to create them.")

# Load vectorstores:
proj_vectorstore_path: str = "./databases/proj"
proj_vectorstore = load_vectorstore(proj_vectorstore_path, embedding_function=baseline_hfe)

strat26_vectorstore_path: str = "./databases/strat26"
strat26_vectorstore = load_vectorstore(strat26_vectorstore_path, embedding_function=baseline_hfe)

strat28_vectorstore_path: str = "./databases/strat28"
strat28_vectorstore = load_vectorstore(strat28_vectorstore_path, embedding_function=baseline_hfe)
# Out:
# One or more vectorstores are missing. Please run milcon_doc_vectorstore.py to create them.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       8 # Load vectorstores:
#       9 proj_vectorstore_path: str = "./databases/proj"
# ---> 10 proj_vectorstore = load_vectorstore(proj_vectorstore_path, embedding_function=baseline_hfe)
#      12 strat26_vectorstore_path: str = "./databases/strat26"
#      13 strat26_vectorstore = load_vectorstore(strat26_vectorstore_path, embedding_function=baseline_hfe)
#
# NameError: name 'load_vectorstore' is not defined
